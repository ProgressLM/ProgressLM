# %%
import os
import json
import random
import pandas as pd
from collections import defaultdict

# ===================== 配置区 =====================

INPUT_JSONL = '/projects/p32958/chengxuan/ProgressLM/data/train/rl/raw/visual_27k_rl_raw.jsonl'
OUTPUT_DIR  = '/projects/p32958/chengxuan/ProgressLM/data/train/rl/raw'
SFT_JSONL   = os.path.join(OUTPUT_DIR, 'visual_16k_normal_view_rl.jsonl')
RL_JSONL    = os.path.join(OUTPUT_DIR, 'visual_16k_normal_view_others.jsonl')
SPLIT_RATIO = 0.6   # SFT 占 10%，RL 占 90%
SEED = 42
# =================================================

def ensure_dir(path: str):
    os.makedirs(path, exist_ok=True)

def extract_action_type(id_string: str):
    parts = id_string.split('/')
    if len(parts) >= 2:
        return parts[1]
    return None

def load_jsonl(jsonl_path: str):
    data = []
    with open(jsonl_path, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                data.append(json.loads(line))
    print(f"✓ 成功加载 {len(data)} 条数据")
    return data

def group_by_trajectory(data):
    """
    将数据按完整 id（即轨迹）聚合。
    返回: {action_type: {trajectory_id: [items...] } }
    """
    grouped = defaultdict(lambda: defaultdict(list))
    for item in data:
        tid = item.get('id', '')
        act = extract_action_type(tid)
        if act:
            grouped[act][tid].append(item)
    return grouped

def dump_jsonl(data, out_path: str):
    with open(out_path, 'w', encoding='utf-8') as f:
        for item in data:
            f.write(json.dumps(item, ensure_ascii=False) + '\n')

def main():
    random.seed(SEED)
    ensure_dir(OUTPUT_DIR)

    # 1) 加载数据
    data = load_jsonl(INPUT_JSONL)

    # 2) 按类别 & 轨迹分组
    grouped = group_by_trajectory(data)
    print(f"✓ 共发现 {len(grouped)} 个类别（基于 extract_action_type）\n")

    # 3) 分层划分 SFT / RL
    sft_data, rl_data = [], []

    category_stats = []  # 用于打印统计
    for act, traj_map in grouped.items():
        traj_ids = list(traj_map.keys())
        random.shuffle(traj_ids)

        # 计算 SFT 轨迹数量，确保至少有1个
        sft_count = max(1, int(len(traj_ids) * SPLIT_RATIO))
        
        # 特殊情况处理：如果只有1个轨迹
        if len(traj_ids) == 1:
            # 选项1：同时放入SFT和RL（数据会重复）
            sft_traj = traj_ids[:]
            rl_traj = traj_ids[:]
            
            # 选项2：只放入SFT（如果不想要数据重复，使用这个）
            # sft_traj = traj_ids[:]
            # rl_traj = []
        else:
            # 正常情况：按比例分配，但确保SFT至少有1个
            sft_traj = traj_ids[:sft_count]
            rl_traj = traj_ids[sft_count:]

        # 收集数据
        sft_items = [item for tid in sft_traj for item in traj_map[tid]]
        rl_items = [item for tid in rl_traj for item in traj_map[tid]]

        sft_data.extend(sft_items)
        rl_data.extend(rl_items)

        # 记录统计
        category_stats.append({
            '类别': act,
            '总轨迹数': len(traj_ids),
            'SFT_轨迹数': len(sft_traj),
            'RL_轨迹数': len(rl_traj),
            'SFT_样本数': len(sft_items),
            'RL_样本数': len(rl_items),
            '重复': '是' if len(traj_ids) == 1 and len(rl_traj) > 0 else '否'
        })

    # 4) 写出文件
    dump_jsonl(sft_data, SFT_JSONL)
    dump_jsonl(rl_data, RL_JSONL)

    # 5) 打印统计信息
    print("\n====== 数据集划分完成 ======")
    print(f"总类别数: {len(category_stats)}")
    print(f"目标比例 SFT : RL = {SPLIT_RATIO:.0%} : {1-SPLIT_RATIO:.0%}\n")

    print("类别分布统计:")
    print("-" * 80)
    print(f"{'类别':20s} | {'总轨迹':6s} | {'SFT轨迹':7s} {'RL轨迹':7s} | {'SFT样本':7s} {'RL样本':7s} | {'重复':4s}")
    print("-" * 80)
    
    total_trajs = 0
    single_traj_categories = 0
    
    for stat in category_stats:
        print(f"{stat['类别']:20s} | {stat['总轨迹数']:6d} | "
              f"{stat['SFT_轨迹数']:7d} {stat['RL_轨迹数']:7d} | "
              f"{stat['SFT_样本数']:7d} {stat['RL_样本数']:7d} | "
              f"{stat['重复']:4s}")
        total_trajs += stat['总轨迹数']
        if stat['总轨迹数'] == 1:
            single_traj_categories += 1
    
    print("-" * 80)
    print(f"汇总: SFT 总样本数: {len(sft_data)}   RL 总样本数: {len(rl_data)}")
    print(f"      总轨迹数: {total_trajs}   只有1个轨迹的类别数: {single_traj_categories}")
    
    # 验证每个类别都有SFT数据
    missing_sft = [stat['类别'] for stat in category_stats if stat['SFT_轨迹数'] == 0]
    if missing_sft:
        print(f"\n⚠️ 警告：以下类别没有SFT数据: {missing_sft}")
    else:
        print(f"\n✅ 验证通过：所有 {len(category_stats)} 个类别都有至少1个轨迹在SFT中")
    
    print(f"\n👉 输出文件已生成:\n   - {SFT_JSONL}\n   - {RL_JSONL}\n")

if __name__ == '__main__':
    main()
# Out:
# ✓ 成功加载 27690 条数据
# ✓ 共发现 107 个类别（基于 extract_action_type）
#
#
# ====== 数据集划分完成 ======
# 总类别数: 107
# 目标比例 SFT : RL = 60% : 40%
#
# 类别分布统计:
# --------------------------------------------------------------------------------
# 类别                   | 总轨迹    | SFT轨迹   RL轨迹    | SFT样本   RL样本    | 重复
# --------------------------------------------------------------------------------
# plug_insertion_v2    |     32 |      19      13 |     714     492 | 否
# put_square_bread_in_trash_can |      4 |       2       2 |      24      30 | 否
# place_in_bread_in_basket_1 |     40 |      24      16 |     321     210 | 否
# place_in_take_bread_and_put_in_plate |     38 |      22      16 |     315     225 | 否
# 9_appleyellowplate_2 |     25 |      15      10 |     318     219 | 否
# 10_packplate_2       |      9 |       5       4 |     114      96 | 否
# 36_putpepper         |     27 |      16      11 |     327     222 | 否
# seal_stamping        |     33 |      19      14 |     384     246 | 否
# throw_battery        |     39 |      23      16 |     441     279 | 否
# gear_place           |     36 |      21      15 |     396     285 | 否
# slide_close_cabinet  |     17 |      10       7 |     129      87 | 否
# tool_liftn_box_place |     26 |      15      11 |     255     186 | 否
# close_drawer         |     15 |       9       6 |     108      72 | 否
# battery_insertion_with_pullout |     36 |      21      15 |     369     258 | 否
# place_in_bread_on_table_2 |     48 |      28      20 |     402     288 | 否
# close_cap_trash_can_1 |     37 |      22      15 |     267     186 | 否
# put_pear_in_top_white_drawer |     10 |       6       4 |      90      48 | 否
# 15_steamegg_2        |     30 |      18      12 |     351     237 | 否
# pick_up_long_bread   |      4 |       2       2 |      27      33 | 否
# place_in_toy         |     43 |      25      18 |     354     234 | 否
# 20_takecorn          |     17 |      10       7 |     195     117 | 否
# pick_up_green_onion  |      4 |       2       2 |      27      30 | 否
# place_in_shape       |     31 |      18      13 |     357     252 | 否
# green_pepper_in_basket |     20 |      12       8 |     177      99 | 否
# 2_cornoven           |     29 |      17      12 |     288     219 | 否
# place_in_cylinder    |     40 |      24      16 |     366     234 | 否
# open_top_drawer      |     24 |      14      10 |     168     120 | 否
# 18_makebread_2       |     35 |      21      14 |     411     270 | 否
# yellow_pepper_in_basket_1 |     10 |       6       4 |      81      48 | 否
# 19_takebread_2       |     22 |      13       9 |     273     204 | 否
# 18_makebread         |     32 |      19      13 |     423     291 | 否
# 7_applegreenplate_2  |     25 |      15      10 |     312     213 | 否
# close_cap_tool_box   |     40 |      24      16 |     339     219 | 否
# 35_putcarrot         |     34 |      20      14 |     414     294 | 否
# plug_extract_from    |     28 |      16      12 |     288     219 | 否
# nut_place            |     36 |      21      15 |     408     306 | 否
# wipe_panel           |     38 |      22      16 |     672     522 | 否
# place_button         |     30 |      18      12 |     522     366 | 否
# 51_breadoven         |     22 |      13       9 |     240     192 | 否
# 241022_side_pull_open_drawer_1 |      4 |       2       2 |      36      33 | 否
# green_pepper_on_table |     16 |       9       7 |     120      96 | 否
# bread_in_basket_1    |     12 |       7       5 |      99      63 | 否
# put_paper_ball_in_trash_can |      6 |       3       3 |      36      45 | 否
# place_in_block_in_plate_1 |     37 |      22      15 |     321     204 | 否
# put_long_bread_in_trash_can |      4 |       2       2 |      33      33 | 否
# 40_putavocado        |     24 |      14      10 |     309     213 | 否
# put_mangosteen_in_top_white_drawer |     10 |       6       4 |      72      57 | 否
# pick_up_banana       |      3 |       1       2 |      18      27 | 否
# put_triangle_bread_in_pot |      1 |       1       1 |      12      12 | 是
# push_break_pick_shelf_insert_machine_press_switch_place_plate |     15 |       9       6 |     117     102 | 否
# pick_bread_desk      |     39 |      23      16 |     414     273 | 否
# place_in_purple_block_in_plate |     37 |      22      15 |     297     213 | 否
# 12_packcup           |     19 |      11       8 |     243     171 | 否
# place_in_yellow_block_on_table |     38 |      22      16 |     303     219 | 否
# put_donut_in_top_white_drawer |      2 |       1       1 |      12      12 | 否
# put_yellow_pepper_in_top_drawer |      3 |       1       2 |      12      24 | 否
# 241023_pick_pear_from_bowl_1 |      9 |       5       4 |      75      60 | 否
# pick_up_pot_lid      |      3 |       1       2 |      15      27 | 否
# 8_appleblueplate_2   |     26 |      15      11 |     315     228 | 否
# put_bread_slice_in_top_white_drawer |     13 |       7       6 |      96      75 | 否
# put_can_in_trash_can |      5 |       3       2 |      36      24 | 否
# put_round_bread_in_top_white_drawer |      4 |       2       2 |      27      24 | 否
# pick_up_bread        |      3 |       1       2 |      12      30 | 否
# pick_up_bread_slice  |      3 |       1       2 |      15      33 | 否
# bread_in_basket_old  |      7 |       4       3 |      51      36 | 否
# bread_on_table       |     10 |       6       4 |      90      51 | 否
# put_banana_in_top_drawer |      9 |       5       4 |      63      51 | 否
# pick_up_red_pepper   |      2 |       1       1 |      15      12 | 否
# close_top_drawer     |     21 |      12       9 |     150     117 | 否
# 241021_close_trash_bin_1 |      9 |       5       4 |      60      48 | 否
# place_in_bread_on_plate_2 |      6 |       3       3 |      45      39 | 否
# 4_potatobowloven_2   |      5 |       3       2 |      69      45 | 否
# put_long_bread_in_top_white_drawer |      3 |       1       2 |      15      24 | 否
# put_long_bread_in_pot |      3 |       1       2 |      12      36 | 否
# put_donut_in_pot     |      2 |       1       1 |      12      12 | 否
# pick_up_round_bread  |      4 |       2       2 |      30      33 | 否
# put_red_pepper_in_top_white_drawer |      7 |       4       3 |      48      39 | 否
# put_toast_in_top_white_drawer |      1 |       1       1 |      12      12 | 是
# slide_close_drawer   |      4 |       2       2 |      24      24 | 否
# put_plastic_bottle_in_trash_can |      5 |       3       2 |      36      24 | 否
# put_triangle_bread_in_top_white_drawer |      6 |       3       3 |      36      45 | 否
# put_round_bread_in_trash_can |      4 |       2       2 |      24      24 | 否
# open_cap_tool_box    |     21 |      12       9 |     168     132 | 否
# put_bread_slice_in_pot |      3 |       1       2 |      12      27 | 否
# yellow_pepper_on_table |     11 |       6       5 |      75      63 | 否
# put_green_pepper_in_top_white_drawer |      2 |       1       1 |      12      12 | 否
# pick_up_square_bread |      3 |       1       2 |      18      30 | 否
# green_pepper_in_basket_1 |      4 |       2       2 |      27      27 | 否
# pick_up_mangosteen   |      1 |       1       1 |      15      15 | 是
# put_egg_in_top_white_drawer |      2 |       1       1 |      12      12 | 否
# pick_up_paper_ball   |      3 |       1       2 |      24      27 | 否
# pick_up_pear         |      2 |       1       1 |      12      15 | 否
# put_toast_in_pot     |      1 |       1       1 |      12      12 | 是
# pick_up_green_pepper |      2 |       1       1 |      12      15 | 否
# pick_up_round_bread_1 |      1 |       1       1 |      15      15 | 是
# pick_up_can          |      1 |       1       1 |      12      12 | 是
# pick_up_plastic_bottle |      2 |       1       1 |      15      12 | 否
# put_bread_in_pot     |      3 |       1       2 |      12      24 | 否
# pick_up_donut        |      2 |       1       1 |      12      12 | 否
# pick_up_triangle_bread |      3 |       1       2 |      12      24 | 否
# put_green_onion_in_pot |      3 |       1       2 |      12      33 | 否
# put_red_pepper_in_pot |      2 |       1       1 |      12      12 | 否
# pick_up_yellow_pepper |      3 |       1       2 |      12      24 | 否
# pick_up_toast        |      2 |       1       1 |      12      15 | 否
# pick_up_egg          |      2 |       1       1 |      12      12 | 否
# put_yellow_pepper_in_top_white_drawer |      1 |       1       1 |      12      12 | 是
# put_round_bread_in_pot |      1 |       1       1 |      15      15 | 是
# --------------------------------------------------------------------------------
# 汇总: SFT 总样本数: 16068   RL 总样本数: 11727
#       总轨迹数: 1591   只有1个轨迹的类别数: 8
#
# ✅ 验证通过：所有 107 个类别都有至少1个轨迹在SFT中
#
# 👉 输出文件已生成:
#    - /projects/p32958/chengxuan/ProgressLM/data/train/rl/raw/visual_16k_normal_view_rl.jsonl
#    - /projects/p32958/chengxuan/ProgressLM/data/train/rl/raw/visual_16k_normal_view_others.jsonl

# %%
import os
import json
import random
import pandas as pd
from collections import defaultdict

# ===================== 配置区 =====================

INPUT_JSONL = '/projects/p32958/chengxuan/ProgressLM/data/train/rl/raw/text_8k_rl_raw.jsonl'
OUTPUT_DIR  = '/projects/p32958/chengxuan/ProgressLM/data/train/rl/raw'
SFT_JSONL   = os.path.join(OUTPUT_DIR, 'text_positive_6500_rl.jsonl')
RL_JSONL    = os.path.join(OUTPUT_DIR, 'text_positive_rl_others.jsonl')
SPLIT_RATIO = 0.8   # SFT 占 10%，RL 占 90%
SEED = 42
# =================================================

def ensure_dir(path: str):
    os.makedirs(path, exist_ok=True)

def extract_action_type(id_string: str):
    parts = id_string.split('/')
    if len(parts) >= 2:
        return parts[1]
    return None

def load_jsonl(jsonl_path: str):
    data = []
    with open(jsonl_path, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                data.append(json.loads(line))
    print(f"✓ 成功加载 {len(data)} 条数据")
    return data

def group_by_trajectory(data):
    """
    将数据按完整 id（即轨迹）聚合。
    返回: {action_type: {trajectory_id: [items...] } }
    """
    grouped = defaultdict(lambda: defaultdict(list))
    for item in data:
        tid = item.get('id', '')
        act = extract_action_type(tid)
        if act:
            grouped[act][tid].append(item)
    return grouped

def dump_jsonl(data, out_path: str):
    with open(out_path, 'w', encoding='utf-8') as f:
        for item in data:
            f.write(json.dumps(item, ensure_ascii=False) + '\n')

def main():
    random.seed(SEED)
    ensure_dir(OUTPUT_DIR)

    # 1) 加载数据
    data = load_jsonl(INPUT_JSONL)

    # 2) 按类别 & 轨迹分组
    grouped = group_by_trajectory(data)
    print(f"✓ 共发现 {len(grouped)} 个类别（基于 extract_action_type）\n")

    # 3) 分层划分 SFT / RL
    sft_data, rl_data = [], []

    category_stats = []  # 用于打印统计
    for act, traj_map in grouped.items():
        traj_ids = list(traj_map.keys())
        random.shuffle(traj_ids)

        # 计算 SFT 轨迹数量，确保至少有1个
        sft_count = max(1, int(len(traj_ids) * SPLIT_RATIO))
        
        # 特殊情况处理：如果只有1个轨迹
        if len(traj_ids) == 1:
            # 选项1：同时放入SFT和RL（数据会重复）
            sft_traj = traj_ids[:]
            rl_traj = traj_ids[:]
            
            # 选项2：只放入SFT（如果不想要数据重复，使用这个）
            # sft_traj = traj_ids[:]
            # rl_traj = []
        else:
            # 正常情况：按比例分配，但确保SFT至少有1个
            sft_traj = traj_ids[:sft_count]
            rl_traj = traj_ids[sft_count:]

        # 收集数据
        sft_items = [item for tid in sft_traj for item in traj_map[tid]]
        rl_items = [item for tid in rl_traj for item in traj_map[tid]]

        sft_data.extend(sft_items)
        rl_data.extend(rl_items)

        # 记录统计
        category_stats.append({
            '类别': act,
            '总轨迹数': len(traj_ids),
            'SFT_轨迹数': len(sft_traj),
            'RL_轨迹数': len(rl_traj),
            'SFT_样本数': len(sft_items),
            'RL_样本数': len(rl_items),
            '重复': '是' if len(traj_ids) == 1 and len(rl_traj) > 0 else '否'
        })

    # 4) 写出文件
    dump_jsonl(sft_data, SFT_JSONL)
    dump_jsonl(rl_data, RL_JSONL)

    # 5) 打印统计信息
    print("\n====== 数据集划分完成 ======")
    print(f"总类别数: {len(category_stats)}")
    print(f"目标比例 SFT : RL = {SPLIT_RATIO:.0%} : {1-SPLIT_RATIO:.0%}\n")

    print("类别分布统计:")
    print("-" * 80)
    print(f"{'类别':20s} | {'总轨迹':6s} | {'SFT轨迹':7s} {'RL轨迹':7s} | {'SFT样本':7s} {'RL样本':7s} | {'重复':4s}")
    print("-" * 80)
    
    total_trajs = 0
    single_traj_categories = 0
    
    for stat in category_stats:
        print(f"{stat['类别']:20s} | {stat['总轨迹数']:6d} | "
              f"{stat['SFT_轨迹数']:7d} {stat['RL_轨迹数']:7d} | "
              f"{stat['SFT_样本数']:7d} {stat['RL_样本数']:7d} | "
              f"{stat['重复']:4s}")
        total_trajs += stat['总轨迹数']
        if stat['总轨迹数'] == 1:
            single_traj_categories += 1
    
    print("-" * 80)
    print(f"汇总: SFT 总样本数: {len(sft_data)}   RL 总样本数: {len(rl_data)}")
    print(f"      总轨迹数: {total_trajs}   只有1个轨迹的类别数: {single_traj_categories}")
    
    # 验证每个类别都有SFT数据
    missing_sft = [stat['类别'] for stat in category_stats if stat['SFT_轨迹数'] == 0]
    if missing_sft:
        print(f"\n⚠️ 警告：以下类别没有SFT数据: {missing_sft}")
    else:
        print(f"\n✅ 验证通过：所有 {len(category_stats)} 个类别都有至少1个轨迹在SFT中")
    
    print(f"\n👉 输出文件已生成:\n   - {SFT_JSONL}\n   - {RL_JSONL}\n")

if __name__ == '__main__':
    main()
# Out:
# ✓ 成功加载 8012 条数据
# ✓ 共发现 47 个类别（基于 extract_action_type）
#
#
# ====== 数据集划分完成 ======
# 总类别数: 47
# 目标比例 SFT : RL = 80% : 20%
#
# 类别分布统计:
# --------------------------------------------------------------------------------
# 类别                   | 总轨迹    | SFT轨迹   RL轨迹    | SFT样本   RL样本    | 重复
# --------------------------------------------------------------------------------
# place_in_shape       |     32 |      25       7 |     157      48 | 否
# 35_putcarrot         |     37 |      29       8 |     175      47 | 否
# throw_battery        |     39 |      31       8 |     187      46 | 否
# 7_applegreenplate_2  |     31 |      24       7 |     156      45 | 否
# place_in_take_bread_and_put_in_plate |     38 |      30       8 |     141      38 | 否
# place_in_purple_block_in_plate |     38 |      30       8 |     137      37 | 否
# wipe_panel           |     39 |      31       8 |     320      92 | 否
# seal_stamping        |     32 |      25       7 |     154      45 | 否
# place_in_block_in_plate_1 |     37 |      29       8 |     138      37 | 否
# close_cap_trash_can_1 |     37 |      29       8 |     119      32 | 否
# 241023_pick_pear_from_bowl_1 |      9 |       7       2 |      35      10 | 否
# place_in_yellow_block_on_table |     38 |      30       8 |     139      35 | 否
# 15_steamegg_2        |     31 |      24       7 |     145      38 | 否
# pick_bread_desk      |     39 |      31       8 |     183      48 | 否
# place_in_toy         |     42 |      33       9 |     149      43 | 否
# place_in_bread_in_basket_1 |     40 |      32       8 |     141      34 | 否
# gear_place           |     38 |      30       8 |     193      52 | 否
# nut_place            |     38 |      30       8 |     205      49 | 否
# 12_packcup           |     24 |      19       5 |     127      32 | 否
# 241022_side_pull_open_drawer_1 |      5 |       4       1 |      23       5 | 否
# 36_putpepper         |     31 |      24       7 |     148      39 | 否
# place_button         |     32 |      25       7 |     250      64 | 否
# close_cap_tool_box   |     40 |      32       8 |     149      37 | 否
# 19_takebread_2       |     26 |      20       6 |     129      40 | 否
# place_in_bread_on_table_2 |     48 |      38      10 |     180      49 | 否
# plug_insertion_v2    |     32 |      25       7 |     304      78 | 否
# plug_extract_from    |     29 |      23       6 |     138      39 | 否
# 10_packplate_2       |     17 |      13       4 |      96      29 | 否
# 20_takecorn          |     23 |      18       5 |     108      30 | 否
# 18_makebread         |     36 |      28       8 |     186      52 | 否
# place_in_cylinder    |     40 |      32       8 |     161      39 | 否
# 9_appleyellowplate_2 |     28 |      22       6 |     143      37 | 否
# 241021_close_trash_bin_1 |      9 |       7       2 |      28       8 | 否
# 51_breadoven         |     22 |      17       5 |      91      32 | 否
# battery_insertion_with_pullout |     35 |      28       7 |     162      38 | 否
# 2_cornoven           |     31 |      24       7 |     123      38 | 否
# 40_putavocado        |     26 |      20       6 |     130      36 | 否
# close_drawer         |     16 |      12       4 |      48      16 | 否
# 8_appleblueplate_2   |     32 |      25       7 |     160      46 | 否
# slide_close_cabinet  |     18 |      14       4 |      60      16 | 否
# open_cap_tool_box    |     21 |      16       5 |      76      24 | 否
# tool_liftn_box_place |     27 |      21       6 |     120      29 | 否
# 18_makebread_2       |     35 |      28       7 |     163      38 | 否
# push_break_pick_shelf_insert_machine_press_switch_place_plate |     16 |      12       4 |      61      17 | 否
# 4_potatobowloven_2   |      6 |       4       2 |      28      14 | 否
# slide_close_drawer   |      5 |       4       1 |      16       4 | 否
# place_in_bread_on_plate_2 |      6 |       4       2 |      19       9 | 否
# --------------------------------------------------------------------------------
# 汇总: SFT 总样本数: 6301   RL 总样本数: 1711
#       总轨迹数: 1351   只有1个轨迹的类别数: 0
#
# ✅ 验证通过：所有 47 个类别都有至少1个轨迹在SFT中
#
# 👉 输出文件已生成:
#    - /projects/p32958/chengxuan/ProgressLM/data/train/rl/raw/text_positive_6500_rl.jsonl
#    - /projects/p32958/chengxuan/ProgressLM/data/train/rl/raw/text_positive_rl_others.jsonl
